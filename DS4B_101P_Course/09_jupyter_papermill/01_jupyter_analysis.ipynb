# %%
# Hard Code Workspace Directory

# %%
# Ignore Warnings

# %%
# Imports

# Allows us to make markdown programmatically


# Core Packages


# Formatters


# Custom Package

# %%
# Pull Data from Database
# Out:
#       index                      id       date      value  prediction  \
# 0         0           Total Revenue 2011-01-01   483015.0         NaN
# 1         1           Total Revenue 2011-02-01  1162075.0         NaN
# 2         2           Total Revenue 2011-03-01   659975.0         NaN
# 3         3           Total Revenue 2011-04-01  1827140.0         NaN
# 4         4           Total Revenue 2011-05-01   844170.0         NaN
# ...     ...                     ...        ...        ...         ...
# 1579    715  Bikeshop Wichita Speed 2015-10-01   194820.0         NaN
# 1580    716  Bikeshop Wichita Speed 2016-01-01        NaN   119019.25
# 1581    717  Bikeshop Wichita Speed 2016-04-01        NaN   119019.25
# 1582    718  Bikeshop Wichita Speed 2016-07-01        NaN   119019.25
# 1583    719  Bikeshop Wichita Speed 2016-10-01        NaN   119019.25
#
#              ci_lo          ci_hi
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ...            ...            ...
# 1579           NaN            NaN
# 1580 -48542.194193  286580.694193
# 1581 -48542.194193  286580.694193
# 1582 -48542.194193  286580.694193
# 1583 -48542.194193  286580.694193
#
# [1584 rows x 7 columns]

# %%
# Inspect Unique ID's
all_forecast_df['id'].unique()
# Out:
# array(['Total Revenue', 'Category 1 Mountain', 'Category 1 Road',
#        'Category 2 Cross Country Race', 'Category 2 Cyclocross',
#        'Category 2 Elite Road', 'Category 2 Endurance Road',
#        'Category 2 Fat Bike', 'Category 2 Over Mountain',
#        'Category 2 Sport', 'Category 2 Trail', 'Category 2 Triathalon',
#        'Bikeshop Albuquerque Cycles', 'Bikeshop Ann Arbor Speed',
#        'Bikeshop Austin Cruisers', 'Bikeshop Cincinnati Speed',
#        'Bikeshop Columbus Race Equipment', 'Bikeshop Dallas Cycles',
#        'Bikeshop Denver Bike Shop', 'Bikeshop Detroit Cycles',
#        'Bikeshop Indianapolis Velocipedes',
#        'Bikeshop Ithaca Mountain Climbers', 'Bikeshop Kansas City 29ers',
#        'Bikeshop Las Vegas Cycles', 'Bikeshop Los Angeles Cycles',
#        'Bikeshop Louisville Race Equipment',
#        'Bikeshop Miami Race Equipment', 'Bikeshop Minneapolis Bike Shop',
#        'Bikeshop Nashville Cruisers', 'Bikeshop New Orleans Velocipedes',
#        'Bikeshop New York Cycles',
#        'Bikeshop Oklahoma City Race Equipment',
#        'Bikeshop Philadelphia Bike Shop', 'Bikeshop Phoenix Bi-peds',
#        'Bikeshop Pittsburgh Mountain Machines',
#        'Bikeshop Portland Bi-peds', 'Bikeshop Providence Bi-peds',
#        'Bikeshop San Antonio Bike Shop',
#        'Bikeshop San Francisco Cruisers',
#        'Bikeshop Seattle Race Equipment', 'Bikeshop Tampa 29ers',
#        'Bikeshop Wichita Speed'], dtype=object)

# %%
# Filter columns to ones we want
# Out:
#      index               id       date      value     prediction  \
# 0        0    Total Revenue 2011-01-01   483015.0            NaN
# 1        1    Total Revenue 2011-02-01  1162075.0            NaN
# 2        2    Total Revenue 2011-03-01   659975.0            NaN
# 3        3    Total Revenue 2011-04-01  1827140.0            NaN
# 4        4    Total Revenue 2011-05-01   844170.0            NaN
# ..     ...              ...        ...        ...            ...
# 211    139  Category 1 Road 2016-08-01        NaN  505679.213069
# 212    140  Category 1 Road 2016-09-01        NaN  505679.213069
# 213    141  Category 1 Road 2016-10-01        NaN  505679.213069
# 214    142  Category 1 Road 2016-11-01        NaN  505679.213069
# 215    143  Category 1 Road 2016-12-01        NaN  505679.213069
#
#             ci_lo         ci_hi
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 211  31125.839658  980232.58648
# 212  31125.839658  980232.58648
# 213  31125.839658  980232.58648
# 214  31125.839658  980232.58648
# 215  31125.839658  980232.58648
#
# [216 rows x 7 columns]

# %%
# Add a Report Title Programmatically

title = "Forecast Report"

md(f"# {title}")
# Out:
# # Forecast Report

# %%
# Display the ID's in the set that will be part of the report
# Out:
# **Reporting results for:** Total Revenue, Category 1 Mountain, Category 1 Road

# %% [markdown]
# ## Performance Summary

# %%
# Pivot Table Summary
# Out:
# <style  type="text/css" >
# #T_11951_row0_col0,#T_11951_row1_col0,#T_11951_row2_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_11951_row0_col1{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_11951_row0_col2{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_11951_row0_col3{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_11951_row0_col4,#T_11951_row1_col4,#T_11951_row2_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_11951_row1_col1{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_11951_row1_col2{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_11951_row1_col3{
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }#T_11951_row2_col1{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_11951_row2_col2{
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }#T_11951_row2_col3{
#             background-color:  #81badb;
#             color:  #000000;
#         }</style><table id="T_11951_" ><thead>    <tr>        <th class="index_name level0" >year</th>        <th class="col_heading level0 col0" >2011</th>        <th class="col_heading level0 col1" >2012</th>        <th class="col_heading level0 col2" >2013</th>        <th class="col_heading level0 col3" >2014</th>        <th class="col_heading level0 col4" >2015</th>    </tr>    <tr>        <th class="index_name level0" >id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11951_level0_row0" class="row_heading level0 row0" >Category 1 Mountain</th>
#                         <td id="T_11951_row0_col0" class="data row0 col0" >$6,223,210</td>
#                         <td id="T_11951_row0_col1" class="data row0 col1" >$6,809,040</td>
#                         <td id="T_11951_row0_col2" class="data row0 col2" >$9,042,625</td>
#                         <td id="T_11951_row0_col3" class="data row0 col3" >$7,502,750</td>
#                         <td id="T_11951_row0_col4" class="data row0 col4" >$9,577,110</td>
#             </tr>
#             <tr>
#                         <th id="T_11951_level0_row1" class="row_heading level0 row1" >Category 1 Road</th>
#                         <td id="T_11951_row1_col0" class="data row1 col0" >$5,069,675</td>
#                         <td id="T_11951_row1_col1" class="data row1 col1" >$5,354,035</td>
#                         <td id="T_11951_row1_col2" class="data row1 col2" >$7,438,150</td>
#                         <td id="T_11951_row1_col3" class="data row1 col3" >$6,421,335</td>
#                         <td id="T_11951_row1_col4" class="data row1 col4" >$7,594,400</td>
#             </tr>
#             <tr>
#                         <th id="T_11951_level0_row2" class="row_heading level0 row2" >Total Revenue</th>
#                         <td id="T_11951_row2_col0" class="data row2 col0" >$11,292,885</td>
#                         <td id="T_11951_row2_col1" class="data row2 col1" >$12,163,075</td>
#                         <td id="T_11951_row2_col2" class="data row2 col2" >$16,480,775</td>
#                         <td id="T_11951_row2_col3" class="data row2 col3" >$13,924,085</td>
#                         <td id="T_11951_row2_col4" class="data row2 col4" >$17,171,510</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Forecast Summary

# %%
# Plot Forecast
# Out:
# <ggplot: (157899992047)>
